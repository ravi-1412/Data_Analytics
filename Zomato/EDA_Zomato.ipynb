# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_data  = pd.read_csv('zomato.csv',encoding='latin-1')

# %%
country_df = pd.read_excel('Country-Code.xlsx')

# %%
zomato_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
country_df.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
zomato_data.shape
# Out:
# (9551, 21)

# %%
country_df.shape
# Out:
# (15, 2)

# %%
final_df = pd.merge(zomato_data,country_df,on='Country Code',how='left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.shape
# Out:
# (9551, 22)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
final_df.isna().sum()    # Cuisines has null values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
final_df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
final_df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(y='Country',data=final_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %% [markdown]
# ## Observation -
#
#     1. India has 8652 data points which is 90.58% of the total data
#
#     2. Tops three countries are India,United states and United kingdom

# %%
final_df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='Price range',data=final_df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# ## Observation -
#
#     1. Count fall as price increases

# %%
final_df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
final_df[final_df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# ## Observation -
#
#     1. India and UAE has online delivery service

# %%
final_df.groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# ## Observation -
#
#     1. Found which Country has which Currency

# %%
final_df['Cuisines'].value_counts()[:10]
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64

# %% [markdown]
# ## Observation -
#
#     1. Found top 10 Cuisines in the dataset

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# Preforming group by operation on three columns
# reset_index() to convert into pandas dataframe
rating = final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
rating.head()

# %%
ratings = rating.rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
ratings['Rating color'].value_counts()
# Out:
# Orange        10
# Red            7
# Yellow         5
# Green          5
# Dark Green     5
# White          1
# Name: Rating color, dtype: int64

# %% [markdown]
# ## Observation -
#
#     1. When Rating is between 4.5 to 4.9---> Excellent
#     2. When Rating are between 4.0 to 4.4--->very good
#     3. when Rating is between 3.5 to 3.9----> good
#     4. when Rating is between 2.5 to 3.4----> average
#     5. when Rating is between 1.8 to 2.4----> Poor
#     6. When Reating is 0 ----> not rated

# %%
plt.figure(figsize= (12,8),dpi=200)
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
plt.figure(figsize= (12,8),dpi=200)
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', hue = 'Rating color', data = ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# ## Observation -
#
#     1. Not Rated count is very high
#     2. Maximum number of rating are between 2.5 to 3.4

# %%
plt.figure(figsize= (12,8),dpi=200)
sns.countplot(x = 'Rating color', data = ratings, palette =['blue', 'Red', 'Orange', 'Yellow', 'Green','Green'] )
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %% [markdown]
# ## Observation -
#
#     1. Orange color has highest number of counts

# %%
country_city = final_df.groupby(['Country','City']).size().reset_index()
country_city
# Out:
#            Country            City   0
# 0        Australia        Armidale   1
# 1        Australia        Balingup   1
# 2        Australia      Beechworth   1
# 3        Australia     Dicky Beach   1
# 4        Australia    East Ballina   1
# ..             ...             ...  ..
# 136  United States        Valdosta  20
# 137  United States        Vernonia   1
# 138  United States        Waterloo  20
# 139  United States         Weirton   1
# 140  United States  Winchester Bay   1
#
# [141 rows x 3 columns]

# %%
country_city['Country'].value_counts()
# Out:
# India             43
# United States     35
# Australia         23
# Phillipines        9
# South Africa       6
# Canada             4
# Indonesia          4
# United Kingdom     4
# Brazil             3
# UAE                3
# New Zealand        2
# Turkey             2
# Qatar              1
# Singapore          1
# Sri Lanka          1
# Name: Country, dtype: int64

# %%
plt.figure(figsize= (12,8),dpi=200)
country_city['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Observation -
#     1. India has 43 cities where Zomato works
#     2. Top 3 countries are India,United states,Australia where Zomato has major buisness 71.63%

# %%
country_city[country_city['Country']=='India'].value_counts()
# Out:
# Country  City          0
# India    Agra          20      1
#          Noida         1080    1
#          Ludhiana      20      1
#          Mangalore     20      1
#          Mohali        1       1
#          Mumbai        20      1
#          Mysore        20      1
#          Nagpur        20      1
#          Nashik        20      1
#          New Delhi     5473    1
#          Panchkula     1       1
#          Kolkata       20      1
#          Patna         20      1
#          Puducherry    20      1
#          Pune          20      1
#          Ranchi        20      1
#          Secunderabad  2       1
#          Surat         20      1
#          Vadodara      20      1
#          Varanasi      20      1
#          Lucknow       21      1
#          Kochi         20      1
#          Ahmedabad     21      1
#          Coimbatore    20      1
#          Allahabad     20      1
#          Amritsar      21      1
#          Aurangabad    20      1
# ...

# %% [markdown]
# ## Observation -
#     1. Found India's 43 cities Name where Zomato works with number of orders

# %%
final_df['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %% [markdown]
# ## Observation -
#     1. Top 3 Restaurant names are Cafe Coffee Day,Domino's Pizza,Subway

# %%
final_df['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %% [markdown]
# ## Observation -
#     1. Top 3 cities with highest number of orders New Delhi,Gurgaon,Noida

# %% [markdown]
# ## MANY MORE INSIGHTS CAN BE MADE

# %% [markdown]
# ### CONTINUED......................
